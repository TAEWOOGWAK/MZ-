# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/MZ/
# Out:
# /content/drive/MyDrive/MZ

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MZ

# %%
# !ls
# Out:
# file.csv  MZ특.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('file.csv')
data = pd.DataFrame(data)
#data = data.drop(['index'], axis =1)

# %%
data
# Out:
#                                                   image  \
# 0     https://media.istockphoto.com/photos/you-alway...
# 1     https://media.istockphoto.com/photos/enjoying-...
# 2     https://media.istockphoto.com/photos/happy-fam...
# 3     https://media.istockphoto.com/photos/young-afr...
# 4     https://media.istockphoto.com/photos/retired-c...
# ...                                                 ...
# 2035  https://media.istockphoto.com/photos/beautiful...
# 2036  https://media.istockphoto.com/photos/calm-fema...
# 2037  https://media.istockphoto.com/photos/colleague...
# 2038  https://media.istockphoto.com/photos/happy-you...
# 2039  https://media.istockphoto.com/photos/give-me-h...
#
#                                                 caption
# 0     You always make my day! Shot of a mature woman...
# 1     Enjoying the fresh sea air Cropped view of a y...
# 2     happy family father and child on meadow with a...
# 3     Young african woman smiling at sunset Portrait...
# 4     Retired Couple Sitting On Bench With Hot Drink...
# ...                                                 ...
# 2035  Beautiful portrait of a mother playing with he...
# 2036  Calm female executive meditating taking break ...
# 2037  Colleagues meeting in office and discussing ov...
# 2038  Happy young woman listening to the music Side ...
# 2039  Give me high five, we have done a great traini...
#
# [2040 rows x 2 columns]

# %%
data['image'][0]
# Out:
# 'https://media.istockphoto.com/photos/you-always-make-my-day-picture-id1125719715?k=6&m=1125719715&s=612x612&w=0&h=OX7BfG5N8KdZfbKmJick3fN3ZJ6AiPWHKg4kp-Sy0sc='

# %%
import os
import time

# 다운받을 이미지 url
url = "https://media.istockphoto.com/photos/you-always-make-my-day-picture-id1125719715?k=6&m=1125719715&s=612x612&w=0&h=OX7BfG5N8KdZfbKmJick3fN3ZJ6AiPWHKg4kp-Sy0sc="

# time check
start = time.time()

# curl 요청
os.system("curl " + url + " > test.jpg")

# 이미지 다운로드 시간 체크
print(time.time() - start)

# 저장 된 이미지 확인
# Out:
# 0.022581100463867188
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-105-47f3f50f807b> in <module>()
#      15
#      16 # 저장 된 이미지 확인
# ---> 17 img = Image.open("test.jpg")
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2894         warnings.warn(message)
#    2895     raise UnidentifiedImageError(
# -> 2896         "cannot identify image file %r" % (filename if filename else fp)
#    2897     )
#    2898
#
# UnidentifiedImageError: cannot identify image file 'test.jpg'

# %%
test.jpg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-9ad87337ea07> in <module>()
# ----> 1 test.jpg
#
# NameError: name 'test' is not defined

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408 at 0x7FC2C8703050>
